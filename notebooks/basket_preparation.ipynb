# %% [markdown]
# # Basket preparation

# %%
cleaned_path="data/processed/cleaned.parquet"
output_basket_path="data/processed/basket_bool.parquet"

# %%
import pandas as pd
from src.apriori_library import BasketPreparer

# %%
df = pd.read_parquet(cleaned_path)
basket_bool = BasketPreparer().to_basket_bool(df)
print(basket_bool.shape)
basket_bool.iloc[:5,:8]

# %%
basket_bool.to_parquet(output_basket_path)
